# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
import pandas as pd
import numpy as np
import requests
import time
import pprint
from scipy.stats import linregress

# Import the OpenWeatherMap API key and output path
from api_keys import weather_api_key
# from api_keys import output_path

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
from api_keys import output_path

# %%
print(output_path)
# Out:
# S:\BootCamp\Challenges\python-api-challenge\output_data\

# %%
BASE_URL = 'https://api.openweathermap.org/data/2.5/weather?appid=' + weather_api_key + '&units=imperial'
NUM_POINTS = 50    # DEBUG 1500

HTTP_STATUS_OK = 200
HTTP_STATUS_NOT_FOUND = 404

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the cities' names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=NUM_POINTS)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=NUM_POINTS)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 41

# %%
# Make a single API call to see what the data returned looks like

sample_weather = 'https://api.openweathermap.org/data/2.5/weather?lat=31.84353411571213&lon=71.30318609462759&appid=' + weather_api_key

sample_weather_result = requests.get(sample_weather)
pprint.pp(sample_weather_result.json())
# Out:
# {'coord': {'lon': 71.3032, 'lat': 31.8435},
#  'weather': [{'id': 800,
#               'main': 'Clear',
#               'description': 'clear sky',
#               'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 309.83,
#           'feels_like': 314.48,
#           'temp_min': 309.83,
#           'temp_max': 309.83,
#           'pressure': 998,
#           'humidity': 42,
#           'sea_level': 998,
#           'grnd_level': 978},
#  'visibility': 10000,
#  'wind': {'speed': 4.95, 'deg': 111, 'gust': 6.6},
#  'clouds': {'all': 1},
#  'dt': 1689536657,
#  'sys': {'country': 'PK', 'sunrise': 1689553220, 'sunset': 1689603661},
#  'timezone': 18000,
#  'id': 1179496,
#  'name': 'Dullewala',
#  'cod': 200}

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = BASE_URL + '&q=' + city.replace(' ', '+')
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    city_response = requests.get(city_url)
    status_code = city_response.status_code
    
    # Run an API request for each of the cities
    if status_code == HTTP_STATUS_OK:
        # Parse the JSON and retrieve data
        city_weather = city_response.json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all'] # this is the percent coverage expressed as an integer
        city_wind_spd = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind_spd,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    elif status_code == HTTP_STATUS_NOT_FOUND:
        print(f"City {city} Not found. Skipping...")
    else:
        raise ValueError(f"Unknown status code {status_code} for city {city}")
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | madalena
# Processing Record 2 of Set 1 | sitka
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | edinburgh of the seven seas
# Processing Record 5 of Set 1 | magadan
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | wynyard
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | baikonur
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | crane
# Processing Record 15 of Set 1 | hamilton
# Processing Record 16 of Set 1 | ebaye
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | dudinka
# Processing Record 19 of Set 1 | port augusta
# Processing Record 20 of Set 1 | alo
# Processing Record 21 of Set 1 | vilyuchinsk
# Processing Record 22 of Set 1 | kostel
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | kon tum
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | uvira
# Processing Record 27 of Set 1 | puerto natales
# Processing Record 28 of Set 1 | rancheria payau
# Processing Record 29 of Set 1 | akrehamn
# Processing Record 30 of Set 1 | vorgashor
# Processing Record 31 of Set 1 | kristiansund
# Processing Record 32 of Set 1 | happy valley-goose bay
# Processing Record 33 of Set 1 | hawaiian paradise park
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | margaret river
# Processing Record 36 of Set 1 | zheleznogorsk
# Processing Record 37 of Set 1 | piuma
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | kerikeri
# Processing Record 40 of Set 1 | whitehorse
# Processing Record 41 of Set 1 | gifford
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'itamaraca',
#   'Lat': -7.7478,
#   'Lng': -34.8256,
#   'Max Temp': 73.45,
#   'Humidity': 94,
#   'Cloudiness': 18,
#   'Wind Speed': 3.49,
#   'Country': 'BR',
#   'Date': 1689552015},
#  {'City': "st. john's",
#   'Lat': 47.5649,
#   'Lng': -52.7093,
#   'Max Temp': 70.99,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': 1689551833},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 35.31,
#   'Humidity': 57,
#   'Cloudiness': 59,
#   'Wind Speed': 14.12,
#   'Country': 'TF',
#   'Date': 1689552037},
#  {'City': 'cobija',
#   'Lat': -11.0267,
#   'Lng': -68.7692,
#   'Max Temp': 81.93,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 0.78,
#   'Country': 'BO',
#   'Date': 1689552038},
#  {'City': 'port hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 57.25,
#   'Humidity': 51,
#   'Cloudiness': 7,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': 1689552038},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 51.82,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'NZ',
#   'Date': 1689552038},
#  {'City': 'omaruru',
#   'Lat': -21.4333,
#   'Lng': 15.9333,
#   'Max Temp': 58.32,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 10.74,
#   'Country': 'NA',
#   'Date': 1689552039},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.33,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Date': 1689551821},
#  {'City': 'ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 62.92,
#   'Humidity': 61,
#   'Cloudiness': 2,
#   'Wind Speed': 2.93,
#   'Country': 'AU',
#   'Date': 1689552039},
#  {'City': 'ennepetal',
#   'Lat': 51.2985,
#   'Lng': 7.3629,
#   'Max Temp': 64.49,
#   'Humidity': 74,
#   'Cloudiness': 76,
#   'Wind Speed': 4.9,
#   'Country': 'DE',
#   'Date': 1689552039},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 77.56,
#   'Humidity': 92,
#   'Cloudiness': 45,
#   'Wind Speed': 1.99,
#   'Country': 'EC',
#   'Date': 1689552040},
#  {'City': 'kailua-kona',
#   'Lat': 19.6406,
#   'Lng': -155.9956,
#   'Max Temp': 82.36,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': 1689551909},
#  {'City': 'posse',
#   'Lat': -14.0931,
#   'Lng': -46.3694,
#   'Max Temp': 76.5,
#   'Humidity': 35,
#   'Cloudiness': 76,
#   'Wind Speed': 3.15,
#   'Country': 'BR',
#   'Date': 1689552040},
#  {'City': 'baharly',
#   'Lat': 38.4362,
#   'Lng': 57.4316,
#   'Max Temp': 85.1,
#   'Humidity': 44,
#   'Cloudiness': 51,
#   'Wind Speed': 5.57,
#   'Country': 'TM',
#   'Date': 1689552040},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 50.61,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Country': 'US',
#   'Date': 1689552041},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 80.04,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': 1689552041},
#  {'City': 'nova vicosa',
#   'Lat': -17.8919,
#   'Lng': -39.3719,
#   'Max Temp': 67.14,
#   'Humidity': 96,
#   'Cloudiness': 26,
#   'Wind Speed': 3.29,
#   'Country': 'BR',
#   'Date': 1689552041},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 56.44,
#   'Humidity': 82,
#   'Cloudiness': 2,
#   'Wind Speed': 13.8,
#   'Country': 'NA',
#   'Date': 1689552042},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 89.69,
#   'Humidity': 62,
#   'Cloudiness': 16,
#   'Wind Speed': 7.9,
#   'Country': 'OM',
#   'Date': 1689552042},
#  {'City': 'felege neway',
#   'Lat': 6.3,
#   'Lng': 36.8833,
#   'Max Temp': 61.86,
#   'Humidity': 89,
#   'Cloudiness': 65,
#   'Wind Speed': 1.63,
#   'Country': 'ET',
#   'Date': 1689552042},
#  {'City': 'saint-joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 68.38,
#   'Humidity': 81,
#   'Cloudiness': 32,
#   'Wind Speed': 3.94,
#   'Country': 'RE',
#   'Date': 1689552042},
#  {'City': 'callao',
#   'Lat': -12.0667,
#   'Lng': -77.15,
#   'Max Temp': 70.72,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'PE',
#   'Date': 1689551865},
#  {'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 26.02,
#   'Humidity': 97,
#   'Cloudiness': 72,
#   'Wind Speed': 4.38,
#   'Country': 'CL',
#   'Date': 1689552042},
#  {'City': 'neuchatel',
#   'Lat': 46.9167,
#   'Lng': 6.8333,
#   'Max Temp': 70.02,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CH',
#   'Date': 1689552043},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 16.3,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 3.83,
#   'Country': 'GS',
#   'Date': 1689552043},
#  {'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 68.77,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.67,
#   'Country': 'PN',
#   'Date': 1689552043},
#  {'City': 'minas de marcona',
#   'Lat': -15.2119,
#   'Lng': -75.1103,
#   'Max Temp': 63.55,
#   'Humidity': 60,
#   'Cloudiness': 28,
#   'Wind Speed': 2.71,
#   'Country': 'PE',
#   'Date': 1689552043},
#  {'City': 'kerman',
#   'Lat': 30.2832,
#   'Lng': 57.0788,
#   'Max Temp': 75.06,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'IR',
#   'Date': 1689552044},
#  {'City': 'mizdah',
#   'Lat': 31.4451,
#   'Lng': 12.9801,
#   'Max Temp': 77.27,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'LY',
#   'Date': 1689552044},
#  {'City': 'ruiz',
#   'Lat': 21.95,
#   'Lng': -105.15,
#   'Max Temp': 92.59,
#   'Humidity': 51,
#   'Cloudiness': 33,
#   'Wind Speed': 13.31,
#   'Country': 'MX',
#   'Date': 1689552044},
#  {'City': 'yanchep',
#   'Lat': -31.55,
#   'Lng': 115.6833,
#   'Max Temp': 51.62,
#   'Humidity': 74,
#   'Cloudiness': 37,
#   'Wind Speed': 10.31,
#   'Country': 'AU',
#   'Date': 1689552044},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 35.26,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Date': 1689552044},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 46.29,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'RU',
#   'Date': 1689552045},
#  {'City': 'jabor',
#   'Lat': 5.921,
#   'Lng': 169.6434,
#   'Max Temp': 83.21,
#   'Humidity': 73,
#   'Cloudiness': 85,
#   'Wind Speed': 14.74,
#   'Country': 'MH',
#   'Date': 1689552045},
#  {'City': 'enewetak',
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 82.8,
#   'Humidity': 78,
#   'Cloudiness': 77,
#   'Wind Speed': 15.52,
#   'Country': 'MH',
#   'Date': 1689552045},
#  {'City': 'belyy yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 58.89,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': 1689552045},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 76.55,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Country': 'US',
#   'Date': 1689552045},
#  {'City': 'hotan',
#   'Lat': 37.0997,
#   'Lng': 79.9269,
#   'Max Temp': 82.08,
#   'Humidity': 18,
#   'Cloudiness': 82,
#   'Wind Speed': 4.97,
#   'Country': 'CN',
#   'Date': 1689552045},
#  {'City': 'sassandra',
#   'Lat': 4.95,
#   'Lng': -6.0833,
#   'Max Temp': 74.25,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 2.93,
#   'Country': 'CI',
#   'Date': 1689552046},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 54.32,
#   'Humidity': 81,
#   'Cloudiness': 83,
#   'Wind Speed': 6.55,
#   'Country': 'ZA',
#   'Date': 1689552046},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 94.17,
#   'Humidity': 43,
#   'Cloudiness': 13,
#   'Wind Speed': 18.84,
#   'Country': 'US',
#   'Date': 1689552046},
#  {'City': "sovetskaya gavan'",
#   'Lat': 48.9723,
#   'Lng': 140.2878,
#   'Max Temp': 62.55,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': 1689552046},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 76.8,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': 1689551560}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_weather_df = pd.DataFrame(city_data)

# Show Record Count
city_weather_df.count()
# Out:
# City          41
# Lat           41
# Lng           41
# Max Temp      41
# Humidity      41
# Cloudiness    41
# Wind Speed    41
# Country       41
# Date          41
# dtype: int64

# %%
# Display sample data
city_weather_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        ribeira brava  32.6500  -17.0667     70.72        68          91
# 1            adamstown -25.0660 -130.1015     69.37        81         100
# 2           georgetown   5.4112  100.3354     84.13        87          20
# 3            kununurra -15.7667  128.7333     82.38        32           5
# 4               waimea  20.0231 -155.6717     83.01        84          65
#
#          Wind Speed Country        Date
# City_ID
# 0              7.14      PT  1689557359
# 1              6.69      PN  1689557359
# 2              2.30      MY  1689557353
# 3             14.97      AU  1689557360
# 4              4.00      US  1689557360

# %%
# Export the City_Data into a csv
city_weather_df.to_csv(f"{output_path}cities.csv", index_label="City_ID")

# %%
# Read saved data
city_weather_df = pd.read_csv(f"{output_path}cities.csv", index_col="City_ID")

# Display sample data
city_weather_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        ribeira brava  32.6500  -17.0667     70.72        68          91
# 1            adamstown -25.0660 -130.1015     69.37        81         100
# 2           georgetown   5.4112  100.3354     84.13        87          20
# 3            kununurra -15.7667  128.7333     82.38        32           5
# 4               waimea  20.0231 -155.6717     83.01        84          65
#
#          Wind Speed Country        Date
# City_ID
# 0              7.14      PT  1689557359
# 1              6.69      PN  1689557359
# 2              2.30      MY  1689557353
# 3             14.97      AU  1689557360
# 4              4.00      US  1689557360

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = city_weather_df['Lat']
y = city_weather_df['Max Temp']
colors = city_weather_df['Max Temp']

# Incorporate the other graph properties
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors, cmap='Spectral_r', alpha=0.9, edgecolors='black')
ax.set(xlabel='Latitude', ylabel='Max Temperature (F)',
      title='City Latitude vs. Max Temperature (July 16, 2023)')
ax.grid()

# Save the figure
plt.savefig(f"{output_path}Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x = city_weather_df['Lat']
y = city_weather_df['Humidity']
colors = city_weather_df['Humidity'] 

# Incorporate the other graph properties
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors, cmap='PuRd', alpha=0.9, edgecolors='black')
ax.set(xlabel='Latitude', ylabel='Humidity (%)',
      title='City Latitude vs. % Humidity (July 16, 2023)')
ax.grid()
# Save the figure
plt.savefig(f"{output_path}Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x = city_weather_df['Lat']
y = city_weather_df['Cloudiness']
colors = city_weather_df['Cloudiness'] 

# Incorporate the other graph properties
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors, cmap='Greys', alpha=.95, edgecolors='black')
ax.set(xlabel='Latitude', ylabel='% Cloud Coverage',
      title='City Latitude vs. Cloud Coverage (July 16, 2023)')
ax.grid()

# Save the figure
plt.savefig(f"{output_path}Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed -- should be wind speed vs latituxxde
x = city_weather_df['Lat']
y = city_weather_df['Wind Speed']
colors = city_weather_df['Wind Speed']

# Incorporate the other graph properties
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors, cmap='Blues', alpha=.95, edgecolors='black')
ax.set(xlabel='Latitude', ylabel='Wind Speed (mph)',
      title='City Latitude vs. Wind Speed (July 16, 2023)')
ax.grid()

# Save the figure
plt.savefig(f"{output_path}Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_weather_df[city_weather_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        ribeira brava  32.6500  -17.0667     70.72        68          91
# 2           georgetown   5.4112  100.3354     84.13        87          20
# 4               waimea  20.0231 -155.6717     83.01        84          65
# 5            iskateley  67.6803   53.1512     57.99        91          99
# 7                lihue  21.9789 -159.3672     83.79        69         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.14      PT  1689557359
# 2              2.30      MY  1689557353
# 4              4.00      US  1689557360
# 5              6.15      RU  1689557360
# 7             16.11      US  1689557361

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_weather_df[city_weather_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             adamstown -25.0660 -130.1015     69.37        81         100
# 3             kununurra -15.7667  128.7333     82.38        32           5
# 6              waitangi -43.9535 -176.5597     51.82        83          99
# 9          port lincoln -34.7333  135.8667     52.83        62           0
# 10       port elizabeth -33.9180   25.5701     48.49        93           0
#
#          Wind Speed Country        Date
# City_ID
# 1              6.69      PN  1689557359
# 3             14.97      AU  1689557360
# 6              5.99      NZ  1689557361
# 9              8.43      AU  1689557361
# 10             4.61      ZA  1689557362

# %%
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             adamstown -25.0660 -130.1015     69.37        81         100
# 3             kununurra -15.7667  128.7333     82.38        32           5
# 6              waitangi -43.9535 -176.5597     51.82        83          99
# 9          port lincoln -34.7333  135.8667     52.83        62           0
# 10       port elizabeth -33.9180   25.5701     48.49        93           0
#
#          Wind Speed Country        Date
# City_ID
# 1              6.69      PN  1689557359
# 3             14.97      AU  1689557360
# 6              5.99      NZ  1689557361
# 9              8.43      AU  1689557361
# 10             4.61      ZA  1689557362

# %%
regression_plot('wind', 'n')
# Out:
# The r-value is: -0.07015612458170906
# The regression line equation is: y = -0.02x + 9.22

# %%
# Define a function to create Linear Regression plots
# Possible values for y_col_name: temperature, humidity, clouds, wind
# Possible values for hemisphere: n, s

def regression_plot(y_col_name, hemisphere):
    # select dataframe to use based on hemisphere passed to the function
    if hemisphere.lower() == 'n':
        df = northern_hemi_df
    elif hemisphere.lower() == 's':
        df = southern_hemi_df
    else:
        raise ValueError(f"Unknown value input for hemisphere: {hemisphere}. Please choose 'n' or 's'.")
      
    # get the date the data was retrieved
    timestamp = df['Date'].iloc[0]
    dt = time.localtime(timestamp)
    mmddyy = f"{dt[1]}-{dt[2]}-{dt[0]}"
            
    # select y axis, colors, labels, line position, based on parameter chosen
    if y_col_name == 'temperature':
        y_data = df['Max Temp']
        colorscheme = 'Spectral_r'
        ylabel_name = 'Max Temperature (F)'
        line_pos = [-50, 110]
        
    elif y_col_name == 'humidity':
        y_data = df['Humidity']
        colorscheme = 'PuRd'
        ylabel_name = 'Humidity (%)'
        line_pos = [-50, 35]
        
    elif y_col_name == 'clouds':
        y_data = df['Cloudiness']
        colorscheme = 'Greys'
        ylabel_name = 'Cloud Coverage (%)'
        line_pos = [40, 40 ]
        
    elif y_col_name == 'wind':
        y_data = df['Wind Speed']
        colorscheme = 'Blues'
        ylabel_name = 'Wind Speed (mph)'
        line_pos = [40, 25]
        line_pos
        
    else:
        raise ValueError
        (f"Unknown value input for y_col_name: {y_col_name}. Please choose one: 'temperature', 'humidity', 'clouds', or 'wind'.")
    
    # x axis data is always latitude
    x_data = df['Lat']
    xlabel = 'Latitude'
    
    # get ready... and, graph!
    fig, ax = plt.subplots()
    ax.scatter(x_data, y_data, c=y_data, cmap=colorscheme, alpha=.9, edgecolors='black')
    ax.set(xlabel='Latitude', ylabel=ylabel_name, 
           title=f"City Latitude vs. {ylabel_name} on {mmddyy}")
    ax.grid()
    
    # do some statistics stuff
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_data, y_data)
    reg_line_plot_yvals = x * slope + intercept
    reg_line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
    
#    ax.plot(x,reg_line_plot_yvals,color="red")
    
    print(f"The r-value is: {rvalue}")
    print(f"The regression line equation is: {reg_line_eq}")

    ax.annotate(reg_line_eq, xy=line_pos, color='red')
    
    # save the scatter plot
    save_filename = f"{hemisphere}_{y_col_name}_{mmddyy}.png"
    plt.savefig(f"{output_path}{save_filename}")
    
    # draw the scatter plot
    plt.show()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regression_plot('temperature','n')
# Out:
# The r-value is: -0.6587585903110941
# The regression line equation is: y = -0.49x + 92.7

# %%
# Linear regression on Southern Hemisphere
regression_plot('temperature','s')
# Out:
# The r-value is: 0.7061882968869919
# The regression line equation is: y = 0.82x + 83.74

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot('humidity','n')
# Out:
# The r-value is: 0.097765351477776
# The regression line equation is: y = 0.12x + 63.6

# %%
# Southern Hemisphere
regression_plot('humidity','s')
# Out:
# The r-value is: -0.1868421798087262
# The regression line equation is: y = -0.24x + 64.04

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot('clouds', 'n')
# Out:
# The r-value is: 0.15609063752026975
# The regression line equation is: y = 0.32x + 49.93

# %%
# Southern Hemisphere
regression_plot('clouds', 's')
# Out:
# The r-value is: -0.18592243923373994
# The regression line equation is: y = -0.55x + 29.36

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_plot('wind', 'n')
# Out:
# The r-value is: -0.07015612458170906
# The regression line equation is: y = -0.02x + 9.22

# %%
# Southern Hemisphere
regression_plot('wind','s')
# Out:
# The r-value is: 0.030720331830166384
# The regression line equation is: y = 0.01x + 10.38

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
